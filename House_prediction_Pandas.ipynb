# %%
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option("display.max_columns",None)

# %%
import pandas as pd

# %%
data=pd.read_excel(r"C:\Users\Nandani\Downloads\Home_prediction_mock.xlsx")

# %%
data.shape
# Out:
# (34857, 21)

# %%
print(data.dtypes)
# Out:
# Suburb                   object
# Address                  object
# Rooms                     int64
# Type                     object
# Price                   float64
# Method                   object
# SellerG                  object
# Date             datetime64[ns]
# Distance                float64
# Postcode                float64
# Bedroom2                float64
# Bathroom                float64
# Car                     float64
# Landsize                float64
# BuildingArea            float64
# YearBuilt               float64
# CouncilArea              object
# Lattitude               float64
# Longtitude              float64
# Regionname               object
# Propertycount           float64
# dtype: object

# %%
data.head(5)
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0 2016-09-03       2.5    3067.0       2.0       1.0  1.0     126.0
# 1 2016-12-03       2.5    3067.0       2.0       1.0  1.0     202.0
# 2 2016-02-04       2.5    3067.0       2.0       1.0  0.0     156.0
# 3 2016-02-04       2.5    3067.0       3.0       2.0  1.0       0.0
# 4 2017-03-04       2.5    3067.0       3.0       2.0  0.0     134.0
#
#    BuildingArea  YearBuilt         CouncilArea  Lattitude  Longtitude  \
# ...

# %%
data.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
(data.isnull().sum()/len(data))*100
# Out:
# Suburb            0.000000
# Address           0.000000
# Rooms             0.000000
# Type              0.000000
# Price            21.832057
# Method            0.000000
# SellerG           0.000000
# Date              0.000000
# Distance          0.002869
# Postcode          0.002869
# Bedroom2         23.573457
# Bathroom         23.599277
# Car              25.039447
# Landsize         33.881286
# BuildingArea     60.576068
# YearBuilt        55.386293
# CouncilArea       0.008607
# Lattitude        22.882061
# Longtitude       22.882061
# Regionname        0.008607
# Propertycount     0.008607
# dtype: float64

# %% [raw]
# Fill missing values:
#
# Numerical columns → median
#
# Categorical columns → mode

# %% [raw]
# Price             7610 n  Bedroom2          8217 n
# Bathroom          8226 n
# Car               8728 n
# Landsize         11810 n
# BuildingArea     21115 n
# YearBuilt        19306 n
# CouncilArea          3 c
# Lattitude         7976 n
# Longtitude        7976 n
# Regionname           3 c
# Propertycount        3 n

# %%
data.head(3)
# Out:
#        Suburb          Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford    68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford     85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0 2016-09-03       2.5    3067.0       2.0       1.0  1.0     126.0
# 1 2016-12-03       2.5    3067.0       2.0       1.0  1.0     202.0
# 2 2016-02-04       2.5    3067.0       2.0       1.0  0.0     156.0
#
#    BuildingArea  YearBuilt         CouncilArea  Lattitude  Longtitude  \
# 0           NaN        NaN  Yarra City Council   -37.8014    144.9958
# 1           NaN        NaN  Yarra City Council   -37.7996    144.9984
# 2          79.0     1900.0  Yarra City Council   -37.8079    144.9934
#
#               Regionname  Propertycount
# 0  Northern Metropolitan         4019.0
# 1  Northern Metropolitan         4019.0
# ...

# %%
data["Distance"]=data["Distance"].fillna(data["Distance"].median())

# %%
data["Postcode"]=data["Postcode"].fillna(data["Postcode"].median())

# %%
data["Price"]=data["Price"].fillna(data["Price"].median())

# %%
data["Bedroom2"]=data["Bedroom2"].fillna(data["Bedroom2"].median())

# %%
data["Bathroom"]=data["Bathroom"].fillna(data["Bathroom"].median())

# %%
data["Car"]=data["Car"].fillna(data["Car"].median())

# %%
data["Landsize"]=data["Landsize"].fillna(data["Landsize"].median())

# %%
data["BuildingArea"]=data["BuildingArea"].fillna(data["BuildingArea"].median())

# %%
data["YearBuilt"]=data["YearBuilt"].fillna(data["YearBuilt"].median())

# %%
data["Lattitude"]=data["Lattitude"].fillna(data["Lattitude"].median())

# %%
data["Longtitude"]=data["Longtitude"].fillna(data["Longtitude"].median())

# %%
data["Propertycount"]=data["Propertycount"].fillna(data["Propertycount"].median())

# %%
data["CouncilArea"]=data["CouncilArea"].fillna(data["CouncilArea"].mode()[0])

# %%
data["Regionname"]=data["Regionname"].fillna(data["Regionname"].mode()[0])

# %%
data["YearBuilt"].unique()
# Out:
# array([1970., 1900., 2014., 2006., 1910., 2009., 1860., 1890., 1925.,
#        2005., 2010., 1880., 1985., 2013., 2012., 1920., 1950., 1998.,
#        1930., 2016., 1965., 1960., 1980., 2011., 2015., 1975., 1993.,
#        2003., 1995., 1996., 2000., 1990., 1915., 2004., 2008., 1916.,
#        1962., 1955., 1988., 1953., 1997., 2007., 1967., 1964., 1889.,
#        1888., 1934., 1966., 1935., 1969., 1940., 1938., 1887., 1904.,
#        1972., 1978., 1939., 1945., 1927., 1948., 1947., 1968., 1958.,
#        2017., 1999., 1992., 1961., 1928., 1977., 1919., 1976., 2001.,
#        1926., 1981., 1986., 1943., 1974., 1956., 1936., 1957., 1987.,
#        2002., 1952., 1994., 1949., 1905., 1912., 1924., 1885., 1923.,
#        1918., 1991., 1942., 1973., 2018., 1982., 2106., 1971., 1963.,
#        1931., 1897., 1906., 1883., 1989., 1983., 1937., 1903., 1913.,
#        1830., 1895., 1908., 1917., 1902., 1854., 1850., 1898., 1941.,
# ...

# %% [raw]
# Q4
#
# Remove duplicate rows.

# %%
data.duplicated().sum()
# Out:
# np.int64(1)

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.shape
# Out:
# (34856, 21)

# %%
data.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %% [raw]
# Clean text columns:
# Remove leading/trailing spaces
# Convert to Title Case
# Check unique values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34856 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34856 non-null  object
#  1   Address        34856 non-null  object
#  2   Rooms          34856 non-null  int64
#  3   Type           34856 non-null  object
#  4   Price          34856 non-null  float64
#  5   Method         34856 non-null  object
#  6   SellerG        34852 non-null  object
#  7   Date           34856 non-null  datetime64[ns]
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       34856 non-null  float64
#  11  Bathroom       34856 non-null  float64
#  12  Car            34856 non-null  float64
#  13  Landsize       34856 non-null  float64
#  14  BuildingArea   34856 non-null  float64
#  15  YearBuilt      34856 non-null  float64
#  16  CouncilArea    34856 non-null  object
# ...

# %% [raw]
#  Suburb           object
#  Address          object
#  Type             object
# Method          object
#  SellerG        object
# CouncilArea      object
#  Regionname       object

# %%
data["Suburb"]=data["Suburb"].str.strip().str.title()

# %%
data["Address"]=data["Address"].str.strip().str.title()

# %%
data["Type"]=data["Type"].str.strip().str.title()

# %%
data["Method"]=data["Method"].str.strip().str.title()

# %%
data["SellerG"]=data["SellerG"].str.strip().str.title()

# %%
data["CouncilArea"]=data["CouncilArea"].str.strip().str.title()

# %%
data["Regionname"]=data["Regionname"].str.strip().str.title()

# %%
data["Suburb"].unique()
# Out:
# array(['Abbotsford', 'Airport West', 'Albert Park', 'Alphington',
#        'Altona', 'Altona North', 'Armadale', 'Ascot Vale', 'Ashburton',
#        'Ashwood', 'Avondale Heights', 'Balaclava', 'Balwyn',
#        'Balwyn North', 'Bentleigh', 'Bentleigh East', 'Box Hill',
#        'Braybrook', 'Brighton', 'Brighton East', 'Brunswick',
#        'Brunswick West', 'Bulleen', 'Burwood', 'Camberwell', 'Canterbury',
#        'Carlton North', 'Carnegie', 'Caulfield', 'Caulfield North',
#        'Caulfield South', 'Chadstone', 'Clifton Hill', 'Coburg',
#        'Coburg North', 'Collingwood', 'Doncaster', 'Eaglemont',
#        'Elsternwick', 'Elwood', 'Essendon', 'Essendon North', 'Fairfield',
#        'Fitzroy', 'Fitzroy North', 'Flemington', 'Footscray', 'Glen Iris',
#        'Glenroy', 'Gowanbrae', 'Hadfield', 'Hampton', 'Hampton East',
#        'Hawthorn', 'Heidelberg Heights', 'Heidelberg West', 'Hughesdale',
#        'Ivanhoe', 'Kealba', 'Keilor East', 'Kensington', 'Kew',
# ...

# %%
 Suburb           object        
 Address          object
 Type             object
Method          object        
 SellerG        object
CouncilArea      object
 Regionname       object

# %%
data["Address"].unique()
# Out:
# array(['68 Studley St', '85 Turner St', '25 Bloomburg St', ...,
#        '147A Severn St', '12/37 Stephen St', '3 Tarrengower St'],
#       dtype=object)

# %%
data["Type"].unique()
# Out:
# array(['H', 'U', 'T'], dtype=object)

# %%
data["Method"].unique()
# Out:
# array(['Ss', 'S', 'Vb', 'Sp', 'Pi', 'Sn', 'W', 'Pn', 'Sa'], dtype=object)

# %%
data["SellerG"].unique()
# Out:
# array(['Jellis', 'Biggin', 'Rounds', 'Nelson', 'Collins', 'Dingle',
#        'Purplebricks', 'Greg', 'Philip', 'Little', 'Kay', 'Beller',
#        'Marshall', 'Hockingstuart', 'Brad', 'Maddison', 'Barry',
#        'Airport', 'Considine', 'Rendina', 'Ray', 'Propertyau', 'Mcdonald',
#        'Frank', 'Prof.', 'Harcourts', 'Thomson', 'Buxton', 'Rt',
#        "Sotheby'S", 'Cayzer', 'Chisholm', 'Mcgrath', 'Brace', 'Miles',
#        'Holland', 'Love', 'Thomas', 'Barlow', 'Sweeney', 'Village', 'Jas',
#        'Williams', 'Gunn&Co', 'Burnham', 'Point', 'Compton', 'Fn',
#        'Hunter', 'Raine&Horne', 'Noel', 'Hodges', 'Gary', 'Fletchers',
#        'Woodards', 'Raine', 'Alexkarbon', 'Walshe', 'Weda', 'Stockdale',
#        'Tim', 'Buxton/Marshall', 'Aime', 'Moonee', 'Har', 'Edward', 'Rw',
#        'North', 'Micm', 'Ascend', 'Christopher', 'Morrison', 'Bekdon',
#        'Mandy', 'R&H', 'Fletchers/One', 'Lindellas', 'Appleby', 'Assisi',
# ...

# %%
data["CouncilArea"].unique()
# Out:
# array(['Yarra City Council', 'Moonee Valley City Council',
#        'Port Phillip City Council', 'Darebin City Council',
#        'Hobsons Bay City Council', 'Stonnington City Council',
#        'Boroondara City Council', 'Monash City Council',
#        'Glen Eira City Council', 'Whitehorse City Council',
#        'Maribyrnong City Council', 'Bayside City Council',
#        'Moreland City Council', 'Manningham City Council',
#        'Melbourne City Council', 'Banyule City Council',
#        'Brimbank City Council', 'Kingston City Council',
#        'Hume City Council', 'Knox City Council', 'Maroondah City Council',
#        'Casey City Council', 'Melton City Council',
#        'Greater Dandenong City Council', 'Nillumbik Shire Council',
#        'Cardinia Shire Council', 'Whittlesea City Council',
#        'Frankston City Council', 'Macedon Ranges Shire Council',
#        'Yarra Ranges Shire Council', 'Wyndham City Council',
# ...

# %%
data["Regionname"].unique()
# Out:
# array(['Northern Metropolitan', 'Western Metropolitan',
#        'Southern Metropolitan', 'Eastern Metropolitan',
#        'South-Eastern Metropolitan', 'Eastern Victoria',
#        'Northern Victoria', 'Western Victoria'], dtype=object)

# %% [raw]
# Fix data types:
# Year_Built → int
# Price → float
# Bedrooms & Bathrooms → int

# %%
data["YearBuilt"]=data["YearBuilt"].astype(int)

# %%
data["Price"]=data["Price"].astype(float)

# %%
data["Bedroom2"]=data["Bedroom2"].astype(int)

# %%
data["Bathroom"]=data["Bathroom"].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34856 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34856 non-null  object
#  1   Address        34856 non-null  object
#  2   Rooms          34856 non-null  int64
#  3   Type           34856 non-null  object
#  4   Price          34856 non-null  float64
#  5   Method         34856 non-null  object
#  6   SellerG        34852 non-null  object
#  7   Date           34856 non-null  datetime64[ns]
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       34856 non-null  int64
#  11  Bathroom       34856 non-null  int64
#  12  Car            34856 non-null  float64
#  13  Landsize       34856 non-null  float64
#  14  BuildingArea   34856 non-null  float64
#  15  YearBuilt      34856 non-null  int64
#  16  CouncilArea    34856 non-null  object
# ...

# %% [raw]
# Remove logically incorrect records:
# Bedrooms ≤ 0
# Bathrooms ≤ 0
# Sqft ≤ 0
# Price ≤ 0

# %%
data["Bedroom2"].unique()
# Out:
# array([ 2,  3,  4,  6,  1,  5,  7,  0,  8,  9, 30, 20, 10, 16, 12])

# %%
data=data[(data["Bedroom2"]>0) & (data["Bathroom"]>0) & (data["Price"]>0)]

# %% [raw]
# Standardize column names:
# Lowercase
# Replace spaces with underscore

# %%
data.columns=data.columns.str.lower().str.replace(" ","_")

# %%
data.shape
# Out:
# (34800, 21)

# %%
data.isnull().sum()
# Out:
# suburb           0
# address          0
# rooms            0
# type             0
# price            0
# method           0
# sellerg          4
# date             0
# distance         0
# postcode         0
# bedroom2         0
# bathroom         0
# car              0
# landsize         0
# buildingarea     0
# yearbuilt        0
# councilarea      0
# lattitude        0
# longtitude       0
# regionname       0
# propertycount    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.describe()
# Out:
#               rooms         price                           date  \
# count  34800.000000  3.480000e+04                          34800
# mean       3.031552  1.010988e+06  2017-05-23 20:04:45.517241600
# min        1.000000  8.500000e+04            2016-01-28 00:00:00
# 25%        2.000000  6.950000e+05            2016-11-27 00:00:00
# 50%        3.000000  8.700000e+05            2017-07-08 00:00:00
# 75%        4.000000  1.150000e+06            2017-10-28 00:00:00
# max       16.000000  1.120000e+07            2018-03-17 00:00:00
# std        0.970044  5.722451e+05                            NaN
#
#            distance      postcode      bedroom2      bathroom           car  \
# count  34800.000000  34800.000000  34800.000000  34800.000000  34800.000000
# mean      11.190095   3116.076293      3.066753      1.715632      1.799195
# min        0.000000   3000.000000      1.000000      1.000000      0.000000
# ...

# %%
data.columns
# Out:
# Index(['suburb', 'address', 'rooms', 'type', 'price', 'method', 'sellerg',
#        'date', 'distance', 'postcode', 'bedroom2', 'bathroom', 'car',
#        'landsize', 'buildingarea', 'yearbuilt', 'councilarea', 'lattitude',
#        'longtitude', 'regionname', 'propertycount'],
#       dtype='object')

# %%
data['property_id'] = range(1, len(data)+1)

# %%
data[['property_id',
'suburb','address','rooms','type',
'distance','postcode','bedroom2','bathroom','car','landsize','buildingarea',
'yearbuilt','councilarea','lattitude',
'longtitude','regionname','propertycount']].to_csv("Property_Info.csv", index=False)

data[['property_id','price','method','sellerg','date']].to_csv("Sales_Info.csv", index=False)

data.to_csv("house_prediction_clean.csv",index=False)
