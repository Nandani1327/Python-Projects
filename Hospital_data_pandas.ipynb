# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Nandani\Downloads\Hospital_Readmission_Mock_Data.csv")

# %%
data.shape
# Out:
# (3000, 13)

# %%
data.head(5)
# Out:
#    Patient_ID   Age   Gender        City Admission_Type      Diagnosis  \
# 0           1  69.0     MALE       Delhi         Urgent       Fracture
# 1           2  32.0    male    Bangalore       Elective      Infection
# 2           3  89.0     MALE  Ahmedabad       Emergency  Heart Disease
# 3           4  78.0    male    Bangalore         Urgent  Heart Disease
# 4           5  38.0   Female   Bangalore         Urgent       Diabetes
#
#    Length_of_Stay  Previous_Admissions  Treatment_Cost Insurance_Type  \
# 0               6                    4         63915.0        Private
# 1               3                    2        141516.0        Private
# 2               7                    5         77147.0            NaN
# 3              10                    2         78064.0            NaN
# 4               6                    5         68535.0        Private
#
#    Doctor_Rating Followup_Required Readmitted
# 0            3.1                No         No
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Patient_ID           3000 non-null   int64
#  1   Age                  2807 non-null   float64
#  2   Gender               3000 non-null   object
#  3   City                 3000 non-null   object
#  4   Admission_Type       3000 non-null   object
#  5   Diagnosis            3000 non-null   object
#  6   Length_of_Stay       3000 non-null   int64
#  7   Previous_Admissions  3000 non-null   int64
#  8   Treatment_Cost       2810 non-null   float64
#  9   Insurance_Type       2014 non-null   object
#  10  Doctor_Rating        3000 non-null   float64
#  11  Followup_Required    3000 non-null   object
#  12  Readmitted           3000 non-null   object
# dtypes: float64(3), int64(3), object(7)
# memory usage: 304.8+ KB

# %%
data.isnull().sum()
# Out:
# Patient_ID               0
# Age                    193
# Gender                   0
# City                     0
# Admission_Type           0
# Diagnosis                0
# Length_of_Stay           0
# Previous_Admissions      0
# Treatment_Cost         190
# Insurance_Type         986
# Doctor_Rating            0
# Followup_Required        0
# Readmitted               0
# dtype: int64

# %%
data["Age"]=data["Age"].fillna(data["Age"].median())

# %%
data.isnull().sum()
# Out:
# Patient_ID               0
# Age                      0
# Gender                   0
# City                     0
# Admission_Type           0
# Diagnosis                0
# Length_of_Stay           0
# Previous_Admissions      0
# Treatment_Cost         190
# Insurance_Type         986
# Doctor_Rating            0
# Followup_Required        0
# Readmitted               0
# dtype: int64

# %%
data["Treatment_Cost"]=data["Treatment_Cost"].fillna(data["Treatment_Cost"].median())

# %%
data["Gender"]=data["Gender"].str.strip().str.title()

# %%
data["City"]=data["City"].str.strip().str.title()

# %%
data["City"].unique()
# Out:
# array(['Delhi', 'Bangalore', 'Ahmedabad', 'Mumbai'], dtype=object)

# %%
data["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data["Insurance_Type"].unique()
# Out:
# array(['Private', nan, 'Government'], dtype=object)

# %%
data["Insurance_Type"].mode()
# Out:
# 0    Government
# Name: Insurance_Type, dtype: object

# %%
data["Insurance_Type"].isnull().sum()
# Out:
# np.int64(986)

# %%
data["Insurance_Type"]=data["Insurance_Type"].fillna("Unknown")

# %%
data["Insurance_Type"].value_counts()
# Out:
# Insurance_Type
# Government    1054
# Unknown        986
# Private        960
# Name: count, dtype: int64

# %% [raw]
# Remove invalid records:
# Age < 18
# Length_of_Stay ≤ 0
# Treatment_Cost ≤ 0

# %%
data=data[(data["Age"] >= 18) & (data["Length_of_Stay"] > 0) & (data["Treatment_Cost"] > 0)]

# %%
data["Age"].unique()
# Out:
# array([69., 32., 89., 78., 38., 41., 52., 39., 70., 19., 47., 55., 81.,
#        77., 50., 75., 66., 76., 59., 79., 64., 68., 72., 20., 24., 56.,
#        35., 21., 31., 26., 88., 61., 25., 53., 67., 23., 71., 80., 51.,
#        65., 57., 43., 58., 46., 62., 82., 18., 28., 22., 45., 29., 40.,
#        54., 44., 60., 30., 49., 83., 74., 87., 73., 36., 85., 34., 86.,
#        33., 37., 84., 48., 42., 63., 27.])

# %%
data.columns=data.columns.str.lower().str.replace(" ","_")

# %%
data.columns
# Out:
# Index(['patient_id', 'age', 'gender', 'city', 'admission_type', 'diagnosis',
#        'length_of_stay', 'previous_admissions', 'treatment_cost',
#        'insurance_type', 'doctor_rating', 'followup_required', 'readmitted'],
#       dtype='object')

# %%
data[["patient_id","age","gender","city","insurance_type","followup_required"]].to_csv("Patient_Info1.csv",index=False)

# %%
data[["patient_id","admission_type","diagnosis","length_of_stay","previous_admissions","treatment_cost","doctor_rating","doctor_rating","readmitted"]].to_csv("Admission_Info.csv",index=False)

# %%
data.to_csv("Hospital_clean.csv",index=False)
